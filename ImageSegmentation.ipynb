# %% [markdown]
# <a href="https://colab.research.google.com/github/haseeb1zahid/Data-Analysis-And-Visualization/blob/master/Haseeb_ImageSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %%
# import the necessary packages
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('101.jpg')
image = cv2.resize(image, (0,0), fx=0.4, fy=0.4)

# %%
# define the list of boundaries
boundaries = [
	([255,182,193], [255,189,199]),
	([15,0,0], [36,255,255]),
	([25, 146, 190], [62, 174, 250]),
	([103, 86, 65], [145, 133, 128])
]

# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")
 
    # find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(image, lower, upper)
	output = cv2.bitwise_and(image, image, mask = mask)
 
	# show the images
	cv2_imshow(np.hstack([image, output]))
	cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1192x308 at 0x7F09E8842278>
# <PIL.Image.Image image mode=RGB size=1192x308 at 0x7F09E7E0DB00>
# <PIL.Image.Image image mode=RGB size=1192x308 at 0x7F09E882C438>
# <PIL.Image.Image image mode=RGB size=1192x308 at 0x7F09E882CAC8>

# %%
b = image.copy()
# set green and red channels to 0
b[:, :, 1] = 0
b[:, :, 2] = 0


g = image.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0

r = image.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=596x308 at 0x7F09DFDF9D68>

# %%
# RGB - Green
cv2_imshow(g)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=596x308 at 0x7F09DFDE9400>
# -1

# %%
# RGB - Red
cv2_imshow(r)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=596x308 at 0x7F09DFDE9E48>
# -1

# %%
# RGB - Blue
cv2_imshow(b)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=596x308 at 0x7F09DFDE9E48>
# -1

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color
from skimage import io
image = io.imread('101.jpg') 
plt.imshow(image)
def circle_points(resolution, center, radius):
    """
    Generate points which define a circle on an image.Centre refers to the centre of the circle
    """   
    radians = np.linspace(0, 2*np.pi, resolution)
    c = center[1] + radius*np.cos(radians)#polar co-ordinates
    r = center[0] + radius*np.sin(radians)
    
    return np.array([c, r]).T

# %%
fig, ax = image_show(image)
#1
points = circle_points(200, [100, 260], 85)[:-1]
snake = seg.active_contour(image, points)
ax.plot(points[:, 0], points[:, 1], '--r', lw=3)
ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)

#2
points = circle_points(200, [100, 530], 85)[:-1]
snake = seg.active_contour(image, points)
ax.plot(points[:, 0], points[:, 1], '--r', lw=3)
ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)

#3
points = circle_points(200, [100, 800], 85)[:-1]
snake = seg.active_contour(image, points)
ax.plot(points[:, 0], points[:, 1], '--r', lw=3)
ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)

#4
points = circle_points(200, [100, 1070], 85)[:-1]
snake = seg.active_contour(image, points)
ax.plot(points[:, 0], points[:, 1], '--r', lw=3)
ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)
